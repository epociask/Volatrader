# %%
import pandas as pd
df = pd.read_csv("ethusdt_data_5m")
df = df.drop("high", 1)
df = df.drop("low", 1)
rf = df.iloc[:, :-160]
rf.describe()
# Out:
#               open        close        volume  twocrows_value  \
# count  1071.000000  1071.000000   1071.000000          1071.0
# mean    130.345313   130.362521   5875.927171             0.0
# std       7.906106     7.893497   6830.906287             0.0
# min     115.050000   115.110000      0.000000             0.0
# 25%     124.525000   124.530000   2355.500000             0.0
# 50%     131.020000   131.010000   3843.000000             0.0
# 75%     135.670000   135.660000   6682.500000             0.0
# max     151.800000   151.770000  84289.000000             0.0
#
#        threeblackcrows_value  threeinside_value  threelinestrike_value  \
# count                 1071.0        1071.000000                 1071.0
# mean                     0.0           0.280112                    0.0
# std                      0.0          10.135344                    0.0
# min                      0.0        -100.000000                    0.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = rf.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
import matplotlib.pyplot as plt

plt.show(ax)
